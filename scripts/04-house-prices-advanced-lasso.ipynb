# %% [markdown]
# # House Prices Advanced Regression Techniques - Lasso
#
# - Using Lasso;
# - Filling all missing values;
# - Work with all values;
# - **Target**: *SalePrice*
#
# [Kaggle](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview)

# %%
# Imports

import pandas as pd
import numpy as np

from sklearn.linear_model import LassoCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, \
    mean_absolute_percentage_error, r2_score

# %%
# Configs
sns.set_style('darkgrid')
datasource_base_path = "./../data/"

# %%
# Function to measure results
def results_regression(y_test_ ,y_pred_):
    mse = mean_squared_error(y_test_ ,y_pred_)
    print(f"MSE: {mse}")
    
    rmse = np.sqrt(mse)
    print(f"RMSE: {rmse}")
    
    mae = mean_absolute_error(y_test_ ,y_pred_)
    print(f"MAE: {mae}")
    
    mape = mean_absolute_percentage_error(y_test_ ,y_pred_)
    print(f"MAPE: {mape}")
    
    r2 = r2_score(y_test_ ,y_pred_)
    print(f"R2_SCORE {r2}")

# %%
# Loading train dataset
# View precedent scprits to analyze dataset
data = pd.read_csv("./../data/house-prices-all-columns-filled.csv")
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0    0.315789      0.75     0.207668  0.039258     1.0       1.0          1.0
# 1    0.105263      0.75     0.255591  0.044600     1.0       1.0          1.0
# 2    0.315789      0.75     0.217252  0.052266     1.0       0.0          1.0
# 3    0.368421      0.75     0.191693  0.044368     1.0       0.0          1.0
# 4    0.315789      0.75     0.268371  0.066250     1.0       0.0          1.0
#
#    Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# 0        0.0        1.0        0.0  ...       0.000000        0.0
# 1        0.0        0.5        0.0  ...       0.000000        0.0
# 2        0.0        1.0        0.0  ...       0.000000        0.0
# 3        0.0        0.0        0.0  ...       0.492754        0.0
# 4        0.0        0.5        0.0  ...       0.000000        0.0
#
#    ScreenPorch  PoolArea  MiscVal    MoSold    YrSold  SaleType  \
# 0          0.0       0.0      0.0  0.166667  0.999005       1.0
# 1          0.0       0.0      0.0  0.416667  0.998507       1.0
# 2          0.0       0.0      0.0  0.750000  0.999005       1.0
# 3          0.0       0.0      0.0  0.166667  0.998010       1.0
# 4          0.0       0.0      0.0  1.000000  0.999005       1.0
#
#    SaleCondition  SalePrice
# 0            0.8   0.276159
# 1            0.8   0.240397
# 2            0.8   0.296026
# 3            0.0   0.185430
# 4            0.8   0.331126
#
# [5 rows x 76 columns]

# %% [markdown]
# ## Train model

# %%
X = data.drop('SalePrice', axis=1)
y = data['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %% [markdown]
# ## Run model

# %%
model = LassoCV()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

results_regression(y_test, y_pred)
# Out:
# MSE: 0.0021842069966779955
# RMSE: 0.046735500389725106
# MAE: 0.030011596724567234
# MAPE: 0.13321126897234273
# R2_SCORE 0.821576975613211
