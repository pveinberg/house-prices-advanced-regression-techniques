# %% [markdown]
# # House Prices Advanced Regression Techniques - XGBoost
#
# - Using XGBoost;
# - Filling all missing values;
# - Work with all values;
# - **Target**: *SalePrice*
#
# [Kaggle](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview)

# %%
# Imports
import os 
from datetime import datetime
import pickle

import pandas as pd
import numpy as np

from xgboost import XGBRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, \
    mean_absolute_percentage_error, r2_score

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configs

# Set Seaborn Style
sns.set_style("darkgrid")

# Define a function to measure results
def results_regression(y_test_, y_pred_, _print=False):
    mse = mean_squared_error(y_test_, y_pred_)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test_, y_pred_)
    mape = mean_absolute_percentage_error(y_test_, y_pred_)
    r2 = r2_score(y_test_, y_pred_)

    if _print:
        print(f"MSE: {mse}")
        print(f"RMSE: {rmse}")
        print(f"MAE: {mae}")
        print(f"MAPE: {mape}")
        print(f"R2_SCORE {r2}")
    else:
        return mse, rmse, mae, mape, r2

# %%
data = pd.read_csv("./../data/house-prices-all-columns-filled.csv")
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0    0.315789      0.75     0.207668  0.039258     1.0       1.0          1.0
# 1    0.105263      0.75     0.255591  0.044600     1.0       1.0          1.0
# 2    0.315789      0.75     0.217252  0.052266     1.0       0.0          1.0
# 3    0.368421      0.75     0.191693  0.044368     1.0       0.0          1.0
# 4    0.315789      0.75     0.268371  0.066250     1.0       0.0          1.0
#
#    Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# 0        0.0        1.0        0.0  ...       0.000000        0.0
# 1        0.0        0.5        0.0  ...       0.000000        0.0
# 2        0.0        1.0        0.0  ...       0.000000        0.0
# 3        0.0        0.0        0.0  ...       0.492754        0.0
# 4        0.0        0.5        0.0  ...       0.000000        0.0
#
#    ScreenPorch  PoolArea  MiscVal    MoSold    YrSold  SaleType  \
# 0          0.0       0.0      0.0  0.166667  0.999005       1.0
# 1          0.0       0.0      0.0  0.416667  0.998507       1.0
# 2          0.0       0.0      0.0  0.750000  0.999005       1.0
# 3          0.0       0.0      0.0  0.166667  0.998010       1.0
# 4          0.0       0.0      0.0  1.000000  0.999005       1.0
#
#    SaleCondition  SalePrice
# 0            0.8   0.276159
# 1            0.8   0.240397
# 2            0.8   0.296026
# 3            0.0   0.185430
# 4            0.8   0.331126
#
# [5 rows x 76 columns]

# %%
X = data.drop(columns=["SalePrice"], axis=1)
y = data["SalePrice"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
params = {
    "seed": [42],
    "n_estimators": range(100, 500, 100),
    "learning_rate": [0.3, 0.5],
    "max_depth": [4],
    "min_split_loss": [0],
    "lambda": [1],
    "reg_alpha": [8],
    "objective": [
        "reg:squarederror",
        "reg:squaredlogerror",
        "reg:squarederror_lad"
    ],
    "eval_metric": ["rmse", "rmsle", "mae", "mape", "mphe", "logloss", "error"],
}


model = GridSearchCV(XGBRegressor(), params, scoring='r2', verbose=10)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

display(model.best_estimator_, model.best_params_, model.best_score_)

results_regression(y_test, y_pred, True)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [CV 1/5; 1/168] START eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 1/5; 1/168] END eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.747 total time=   7.3s
# [CV 2/5; 1/168] START eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 2/5; 1/168] END eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.667 total time=   2.7s
# [CV 3/5; 1/168] START eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 3/5; 1/168] END eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.746 total time=   5.9s
# [CV 4/5; 1/168] START eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 4/5; 1/168] END eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.786 total time=   1.0s
# [CV 5/5; 1/168] START eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 5/5; 1/168] END eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.786 total time=   2.9s
# [CV 1/5; 2/168] START eval_metric=rmse, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42
# [CV
168] START eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42
# [CV 1/5; 24/168] END eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42;, score=nan total time=   0.0s
# [CV 2/5; 24/168] START eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42
# [CV 2/5; 24/168] END eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42;, score=nan total time=   0.0s
# [CV 3/5; 24/168] START eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42
# [CV 3/5; 24/168] END eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42;, score=nan total time=   0.0s
# [CV 4/5; 24/168] START eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42
# [CV 4/5; 24/168] END eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42;, score=nan total time=   0.0s
# [CV 5/5; 24/168] START eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42
# [CV 5/5; 24/168] END eval_metric=rmse, lambda=1, learning_rate=0.5, max_depth=4, min_split_loss=0, n_estimators=400, objective=reg:squarederror_lad, reg_alpha=8, seed=42;, score=nan total time=   0.0s
# [CV 1/5; 25/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 1/5; 25/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.747 total time=   1.0s
# [CV 2/5; 25/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 2/5; 25/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.667 total time=   5.2s
# [CV 3/5; 25/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 3/5; 25/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.746 total time=   3.5s
# [CV 4/5; 25/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 4/5; 25/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.786 total time=   1.6s
# [CV 5/5; 25/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42
# [CV 5/5; 25/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squarederror, reg_alpha=8, seed=42;, score=0.786 total time=   7.3s
# [CV 1/5; 26/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42
# [CV 1/5; 26/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42;, score=0.693 total time=   3.1s
# [CV 2/5; 26/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42
# [CV 2/5; 26/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42;, score=0.568 total time=   3.1s
# [CV 3/5; 26/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42
# [CV 3/5; 26/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42;, score=0.710 total time=   0.9s
# [CV 4/5; 26/168] START eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42
# [CV 4/5; 26/168] END eval_metric=rmsle, lambda=1, learning_rate=0.3, max_depth=4, min_split_loss=0, n_estimators=100, objective=reg:squaredlogerror, reg_alpha=8, seed=42;, score=0.717 total time=   1.0s
# ...
#   [bt] (4) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e02f8) [0x79c694ae02f8]
#   [bt] (5) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x79c69493c5f0]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x79c7040c2e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x79c7040bf493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x79c7040e73e9]
#
#
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:15:38] ../src/objective/objective.cc:26: Unknown objective function: `reg:squarederror_lad`
# Objective candidate: survival:aft
# Objective candidate: binary:hinge
# Objective candidate: multi:softmax
# Objective candidate: multi:softprob
# Objective candidate: rank:pairwise
# Objective candidate: rank:ndcg
# Objective candidate: rank:map
# Objective candidate: reg:squarederror
# Objective candidate: reg:squaredlogerror
# Objective candidate: reg:logistic
# Objective candidate: binary:logistic
# Objective candidate: binary:logitraw
# Objective candidate: reg:linear
# Objective candidate: reg:pseudohubererror
# Objective candidate: count:poisson
# Objective candidate: survival:cox
# Objective candidate: reg:gamma
# Objective candidate: reg:tweedie
# Objective candidate: reg:absoluteerror
#
# Stack trace:
#   [bt] (0) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x3708b3) [0x79c694b708b3]
#   [bt] (1) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x370f8f) [0x79c694b70f8f]
#   [bt] (2) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e543c) [0x79c694ae543c]
#   [bt] (3) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ebfd7) [0x79c694aebfd7]
#   [bt] (4) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e02f8) [0x79c694ae02f8]
#   [bt] (5) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x79c69493c5f0]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x79c7040c2e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x79c7040bf493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x79c7040e73e9]
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:15:41] ../src/objective/objective.cc:26: Unknown objective function: `reg:squarederror_lad`
# Objective candidate: survival:aft
# Objective candidate: binary:hinge
# Objective candidate: multi:softmax
# Objective candidate: multi:softprob
# Objective candidate: rank:pairwise
# Objective candidate: rank:ndcg
# Objective candidate: rank:map
# Objective candidate: reg:squarederror
# Objective candidate: reg:squaredlogerror
# Objective candidate: reg:logistic
# Objective candidate: binary:logistic
# Objective candidate: binary:logitraw
# Objective candidate: reg:linear
# Objective candidate: reg:pseudohubererror
# Objective candidate: count:poisson
# Objective candidate: survival:cox
# Objective candidate: reg:gamma
# Objective candidate: reg:tweedie
# Objective candidate: reg:absoluteerror
#
# Stack trace:
#   [bt] (0) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x3708b3) [0x79c694b708b3]
#   [bt] (1) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x370f8f) [0x79c694b70f8f]
#   [bt] (2) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e543c) [0x79c694ae543c]
#   [bt] (3) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ebfd7) [0x79c694aebfd7]
#   [bt] (4) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e02f8) [0x79c694ae02f8]
#   [bt] (5) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x79c69493c5f0]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x79c7040c2e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x79c7040bf493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x79c7040e73e9]
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:15:45] ../src/objective/objective.cc:26: Unknown objective function: `reg:squarederror_lad`
# Objective candidate: survival:aft
# Objective candidate: binary:hinge
# Objective candidate: multi:softmax
# Objective candidate: multi:softprob
# Objective candidate: rank:pairwise
# Objective candidate: rank:ndcg
# Objective candidate: rank:map
# Objective candidate: reg:squarederror
# Objective candidate: reg:squaredlogerror
# Objective candidate: reg:logistic
# Objective candidate: binary:logistic
# Objective candidate: binary:logitraw
# Objective candidate: reg:linear
# Objective candidate: reg:pseudohubererror
# Objective candidate: count:poisson
# Objective candidate: survival:cox
# Objective candidate: reg:gamma
# Objective candidate: reg:tweedie
# Objective candidate: reg:absoluteerror
#
# Stack trace:
#   [bt] (0) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x3708b3) [0x79c694b708b3]
#   [bt] (1) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x370f8f) [0x79c694b70f8f]
#   [bt] (2) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e543c) [0x79c694ae543c]
#   [bt] (3) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ebfd7) [0x79c694aebfd7]
#   [bt] (4) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e02f8) [0x79c694ae02f8]
#   [bt] (5) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x79c69493c5f0]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x79c7040c2e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x79c7040bf493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x79c7040e73e9]
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:15:51] ../src/objective/objective.cc:26: Unknown objective function: `reg:squarederror_lad`
# Objective candidate: survival:aft
# Objective candidate: binary:hinge
# Objective candidate: multi:softmax
# Objective candidate: multi:softprob
# Objective candidate: rank:pairwise
# Objective candidate: rank:ndcg
# Objective candidate: rank:map
# Objective candidate: reg:squarederror
# Objective candidate: reg:squaredlogerror
# Objective candidate: reg:logistic
# Objective candidate: binary:logistic
# Objective candidate: binary:logitraw
# Objective candidate: reg:linear
# Objective candidate: reg:pseudohubererror
# Objective candidate: count:poisson
# Objective candidate: survival:cox
# Objective candidate: reg:gamma
# Objective candidate: reg:tweedie
# Objective candidate: reg:absoluteerror
#
# Stack trace:
#   [bt] (0) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x3708b3) [0x79c694b708b3]
#   [bt] (1) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x370f8f) [0x79c694b70f8f]
#   [bt] (2) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e543c) [0x79c694ae543c]
#   [bt] (3) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ebfd7) [0x79c694aebfd7]
#   [bt] (4) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2e02f8) [0x79c694ae02f8]
#   [bt] (5) /home/pablo_veinberg/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x79c69493c5f0]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x79c7040c2e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x79c7040bf493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x79c7040e73e9]
#
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.74661508 0.67942232        nan 0.74661508 0.67942232        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan
#  0.6858891  0.55458192        nan 0.6858891  0.55458192        nan]
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, lambda=1, learning_rate=0.3,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, min_split_loss=0, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, ...)
# {'eval_metric': 'rmse',
#  'lambda': 1,
#  'learning_rate': 0.3,
#  'max_depth': 4,
#  'min_split_loss': 0,
#  'n_estimators': 100,
#  'objective': 'reg:squarederror',
#  'reg_alpha': 8,
#  'seed': 42}
# 0.7466150781810267
# MSE: 0.0026778128222004417
# RMSE: 0.05174758759788172
# MAE: 0.033495113431158664
# MAPE: 0.16883551434677857
# R2_SCORE 0.7812554106797587
